# %% [markdown]
# Use qiime2-amplicon-2024.5_v3 kernel

# %%
# %%bash
# conda list
# Out:
# # packages in environment at /home/april/miniconda3/envs/qiime2-amplicon-2024.5_v3:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# _r-mutex                  1.0.1               anacondar_1    conda-forge
# _sysroot_linux-64_curr_repodata_hack 3                   h69a702a_16    conda-forge
# alsa-lib                  1.2.11               hd590300_1    conda-forge
# altair                    5.4.1              pyhd8ed1ab_1    conda-forge
# anyio                     4.4.0              pyhd8ed1ab_0    conda-forge
# appdirs                   1.4.4              pyh9f0ad1d_0    conda-forge
# argcomplete               3.5.0              pyhd8ed1ab_0    conda-forge
# argh                      0.31.3             pyhd8ed1ab_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_0    conda-forge
# ...

# %%
# %%bash
# biom convert \
#   -i 16S_forRPCA.biom \
#   -o 16S_forRPCA.hd5.biom \
#   --to-hdf5
#
# #qiime tools import --type 'FeatureTable[Frequency]' --input-path Misame_raw2.biom --output-path Misame_raw2.qza
# Out:
# /home/april/miniconda3/envs/qiime2-amplicon-2024.5_v3/lib/python3.9/site-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
# %%bash
# qiime tools import --type 'FeatureTable[Frequency]' --input-path 16S_forRPCA.hd5.biom --output-path 16S_forRPCA.qza
# Out:
# /home/april/miniconda3/envs/qiime2-amplicon-2024.5_v3/lib/python3.9/site-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# Imported 16S_forRPCA.hd5.biom as BIOMV210DirFmt to 16S_forRPCA.qza

# %%
# %%bash
# qiime gemelli rpca --i-table 16S_forRPCA.qza --output-dir 16S_RPCA
# Out:
# /home/april/miniconda3/envs/qiime2-amplicon-2024.5_v3/lib/python3.9/site-packages/numpy/core/getlimits.py:542: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)
# Saved PCoAResults % Properties('biplot') to: 16S_RPCA/biplot.qza
# Saved DistanceMatrix to: 16S_RPCA/distance_matrix.qza

# %%
# !unzip 16S_RPCA/biplot.qza -d 16S_RPCA/biplot_unzipped
# Out:
# Archive:  16S_RPCA/biplot.qza
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/checksums.md5
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/metadata.yaml
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/VERSION
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/data/ordination.txt
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/provenance/citations.bib
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/provenance/metadata.yaml
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/provenance/VERSION
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/provenance/action/action.yaml
#   inflating: 16S_RPCA/biplot_unzipped/629da861-81c6-48df-a17a-8f24eeca9919/provenance/artifacts/5d70d495-32ff-46e8-92b3-c07f237df82d/citations.bib
# ...
