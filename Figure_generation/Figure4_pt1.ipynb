# %%
import os 
import pandas as pd

# %%
Dropbox_path="/mnt/c/Users/ETTINA03/NYU Langone Health Dropbox/April Jauhal/Shenhav_Lab"
pickle_path = os.path.join(Dropbox_path, "IMiC/Code/machine_learning/for_github/pickles/")
Fig_path = os.path.join(Dropbox_path, "IMiC/Figures")

# %%
# Load plotting functions
# %run "ml_plotting_functions.py"

# %%
# Load targeted BEP data
misame_bep_cs_targeted = pd.read_pickle(os.path.join(pickle_path,'misame_BEP_topfeats_ae.pickle')) 
vital_bep_cs_targeted = pd.read_pickle(os.path.join(pickle_path,'vital_BEP_topfeats_ae.pickle'))  

# Load targeted WAZ data
misame_tar_csWAZ=pd.read_pickle(os.path.join(pickle_path, "misame_wazmargin_crosswaz_ae_pure.pickle"))
vital_tar_csWAZ=pd.read_pickle(os.path.join(pickle_path, "vital_wazmargin_crosswaz_ae_pure.pickle"))
child_tar_csWAZ=pd.read_pickle(os.path.join(pickle_path, "child_wazmargin_crosswaz_ae_pure.pickle"))

# %%
# Load untargeted data
misame_untar_csWAZ=pd.read_pickle(os.path.join(pickle_path, 'misame_cs_overlap_sig_feats_gbm.pickle'))
vital_untar_csWAZ=pd.read_pickle(os.path.join(pickle_path, 'vital_waz_cs_overlap_sig_feats_gbm.pickle'))
child_untar_csWAZ=pd.read_pickle(os.path.join(pickle_path, 'child_waz_cs_overlap_sig_feats_gbm.pickle'))
ut_misame_bep_cs = pd.read_pickle(os.path.join(pickle_path, 'misame_BEP_fromMeanMaxUnionBEP_meta_for_ML_gbm.pickle'))
ut_vital_bep_cs = pd.read_pickle(os.path.join(pickle_path, 'vital_BEP_fromMeanMaxUnionBEP_meta_for_ML_gbm.pickle'))

# %%
# Load 104 feature data
misame_waz_104 = pd.read_pickle(os.path.join(pickle_path, "misame_all_gbm.pickle"))
vital_waz_104 = pd.read_pickle(os.path.join(pickle_path, "vital_waz_all_gbm.pickle"))
child_waz_104 = pd.read_pickle(os.path.join(pickle_path, "child_WAZ_all_gbm.pickle"))
misame_bep_104 = pd.read_pickle(os.path.join(pickle_path, "misame_bep_all_gbm.pickle"))
vital_bep_104 = pd.read_pickle(os.path.join(pickle_path, "vital_bep_all_gbm.pickle"))

# %%
# Baseline models
misame_bep_baseline = pd.read_pickle(os.path.join(pickle_path, "misame_BEP_baseline.pickle"))
vital_bep_baseline = pd.read_pickle(os.path.join(pickle_path, "vital_BEP_baseline.pickle"))
misame_waz_baseline = pd.read_pickle(os.path.join(pickle_path, "misame_wazmargin_baseline.pickle"))
vital_waz_baseline = pd.read_pickle(os.path.join(pickle_path, "vital_wazmargin_baseline.pickle"))
child_waz_baseline = pd.read_pickle(os.path.join(pickle_path, "child_wazmargin_baseline.pickle"))

# %%
fig_legend_labels = ['Targeted', 'Untargeted', 'Untargeted (MS2)', 'Naïve']
fig_colors = ['#0072B2', '#E69F00', '#009E73', '#808080']
fig4A1=compare_plot_ROC_AUC([misame_bep_cs_targeted, ut_misame_bep_cs, misame_bep_104, misame_bep_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="MISAME BEP")
fig4A1.savefig(os.path.join(Fig_path, 'Figure4A1.pdf'), dpi=600)
fig4A2=compare_plot_ROC_AUC([vital_bep_cs_targeted, ut_vital_bep_cs, vital_bep_104, vital_bep_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="Mumta-LW BEP")
fig4A2.savefig(os.path.join(Fig_path, 'Figure4A2.pdf'), dpi=600)
fig4A3=compare_plot_ROC_AUC([misame_tar_csWAZ, misame_untar_csWAZ, misame_waz_104, misame_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="MISAME WAZ")
fig4A3.savefig(os.path.join(Fig_path, 'Figure4A3.pdf'), dpi=600)
fig4A4=compare_plot_ROC_AUC([vital_tar_csWAZ, vital_untar_csWAZ, vital_waz_104, vital_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="Mumta-LW WAZ")
fig4A4.savefig(os.path.join(Fig_path, 'Figure4A4.pdf'), dpi=600)
fig4A5=compare_plot_ROC_AUC([child_tar_csWAZ, child_untar_csWAZ, child_waz_104, child_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="CHILD WAZ")
fig4A5.savefig(os.path.join(Fig_path, 'Figure4A5.pdf'), dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
fig_legend_labels = ['Targeted', 'Untargeted', 'Untargeted (MS2)', 'Naïve']
fig_colors = ['#0072B2', '#E69F00', '#009E73', '#808080']
fig4A6=compare_plot_PR([misame_bep_cs_targeted, ut_misame_bep_cs, misame_bep_104, misame_bep_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="MISAME BEP")
fig4A6.savefig(os.path.join(Fig_path, 'Figure4A6.pdf'), dpi=600)
fig4A7=compare_plot_PR([vital_bep_cs_targeted, ut_vital_bep_cs, vital_bep_104, vital_bep_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="Mumta-LW BEP")
fig4A7.savefig(os.path.join(Fig_path, 'Figure4A7.pdf'), dpi=600)
fig4A8=compare_plot_PR([misame_tar_csWAZ, misame_untar_csWAZ, misame_waz_104, misame_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="MISAME WAZ")
fig4A8.savefig(os.path.join(Fig_path, 'Figure4A8.pdf'), dpi=600)
fig4A9=compare_plot_PR([vital_tar_csWAZ, vital_untar_csWAZ, vital_waz_104, vital_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="Mumta-LW WAZ")
fig4A9.savefig(os.path.join(Fig_path, 'Figure4A9.pdf'), dpi=600)
fig4A10=compare_plot_PR([child_tar_csWAZ, child_untar_csWAZ, child_waz_104, child_waz_baseline], fig_legend_labels, type='mean', colorset = fig_colors, plot_title="CHILD WAZ")
fig4A10.savefig(os.path.join(Fig_path, 'Figure4A10.pdf'), dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
